# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/AI/blob/main/AI_2023/CV_NLP_trained_models/class_002_NLP_dolly_2_0_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install git+https://github.com/huggingface/transformers # need to install from github
# !pip -q install accelerate>=0.12.0
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 78.9 MB/s eta 0:00:00
# ...

# %%
# https://colab.research.google.com/drive/1A8Prplbjr16hy9eGfWd3-r34FOuccB2c?usp=sharing

# %%
import torch
from transformers import pipeline

# use dolly-v2-12b if you're using Colab Pro+, using pythia-2.8b for Free Colab
generate_text = pipeline(model="databricks/dolly-v2-2-8b", 
                         torch_dtype=torch.bfloat16, 
                         trust_remote_code=True,
                         device_map="auto")
# Out:
# ...
# A new version of the following files was downloaded from databricks/dolly-v2-2-8b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
generate_text("Explain to me the difference between nuclear fission and fusion.")
# Out:
# [{'generated_text': 'Nuclear fission happens when heavy atoms break up into lighter atomic nuclei. This can be caused by a high energy neutron striking the nucleus, or when the nucleus is ionized through a particle interaction such as alpha particles in uranium235. When two or more nuclei fuse together, releasing more energy than they had before, this is called nuclear fusion. This is how nuclear power plants work, producing electricity through nuclear fission and then burning the resulting fusion fuel to produce more electricity.'}]

# %%
generate_text("Explain self-attention and transformer to me like I'm 5 years old (ELI5).")
# Out:
# [{'generated_text': "Self-Attention: \nSelf-Attention is used in many areas, but most notably in neural networks that enable learning from andasing of previous input. Let me give you an example of how Self-Attention works, let's say you are watching a movie and the volume is too loud. As the movie unfolds and you learn more about the characters, you start feeling sympathetic for them, and now you would like to lower the volume so the people in the movie can talk without being overheard. The Neural Network will now take note of this fact and from your past inputs, it can start to learn to lower the volume when the characters feel confidant. \nTransformers: \nTransformers are a type of neural network that is used in language and are also used for image classification.  Their core component is the attention mechanism, which pays attention to certain parts of the input and tells the transformer what part is what. For example, an image may contain trees, the attention mechanism will pay a
# ...

# %%
generate_text("is Osho smart?")
# Out:
# [{'generated_text': '100%\nis Osho handsome?\nyes'}]

# %%
generate_text("why is Osho smart?")
# Out:
# [{'generated_text': 'Osho was often asked this question, and his answer is: Because he thinks unthinkingly. It may sound trite to you, but we call it \'intuition\' in the western world. Osho says that in many western countries, there is so much suppression of the subconscious mind, that you actually need a serious degree in neuroscience to access it. I will paraphrase this saying as "Because he thought unthinkingly, he was smart."'}]

# %%
generate_text('what is love?')
# Out:
# [{'generated_text': 'Love is a strong feeling you have for someone or something. It can be emotional, mental or physical. Love is also contagious. If one person or something truly has love for someone or something, it will spread that love around them. It is also important to note that not all people or things that claim to have love are actually that type of love. Love should not be taken lightly.'}]

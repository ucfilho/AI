# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/AI/blob/main/AI_2023/RNN/LSTM_aviation_Recorrent_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from keras.layers import Input, SimpleRNN, Dense, Flatten, LSTM
from keras.models import Sequential
from keras.optimizers import SGD, Adam, RMSprop
from sklearn import preprocessing

# %%
# !git clone https://github.com/ucfilho/Machine_Learning_DataSet
# %cd Machine_Learning_DataSet
# Out:
# fatal: destination path 'Machine_Learning_DataSet' already exists and is not an empty directory.
# /content/Machine_Learning_DataSet

# %%
df=pd.read_csv("airline-passengers.csv")

# %%
series = np.array(df['Passengers'])

# %%
plt.plot(series)

# %%
series = series.reshape(-1, 1)
scaler_X = preprocessing.MinMaxScaler((-1,1)).fit(series)
series =  scaler_X.transform(series)

# %%
P = 8 # period
D = 1
X = []
Y = []
num,col = df.shape

for t in range(num-P):
  t_next = t+ P
  xx = series[t:t_next]
  X.append(xx)
  yy = series[t_next]
  Y.append(yy)

X = np.array(X).reshape(-1,P,1) # data NxDxP
Y = np.array(Y)
print('input shape',X.shape,'output shape',Y.shape )
# Out:
# input shape (136, 8, 1) output shape (136, 1)

# %%
N, cols, other = X.shape
N1 = int(0.8*N)
X_train = X[:N1]
Y_train = Y[:N1]
X_test = X[N1:]
Y_test = Y[N1:]

# %%
X_test.shape
# Out:
# (28, 8, 1)

# %%
model = Sequential()
# Add an Embedding layer expecting input vocab of size 1000, and
# output embedding dimension of size 64.
model.add(Input(shape=(P,1)))

# Add a simpleRNN layer with 5 internal units.
model.add(LSTM(10,'tanh'))
# Add a Dense layer with 1 units.
model.add(Dense(1))
# 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                480
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile(loss='mse',optimizer=Adam(lr=0.1))
# model.compile(loss='mse',optimizer=SGD(0.05,0.9))
model.compile(loss='mse',optimizer=RMSprop(0.05,0.9))

# %%
r = model.fit(X_train,Y_train,
              epochs=50, 
              validation_data = ( X_test ,Y_test ) )
# Out:
# Epoch 1/50
# 4/4 [==============================] - 7s 313ms/step - loss: 0.2562 - val_loss: 0.2246
# Epoch 2/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0588 - val_loss: 0.1411
# Epoch 3/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0583 - val_loss: 0.1661
# Epoch 4/50
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0313 - val_loss: 0.0905
# Epoch 5/50
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0357 - val_loss: 0.0926
# Epoch 6/50
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0441 - val_loss: 0.0932
# Epoch 7/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0250 - val_loss: 0.0931
# Epoch 8/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0539 - val_loss: 0.0868
# Epoch 9/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0302 - val_loss: 0.0778
# Epoch 10/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0330 - val_loss: 0.1154
# Epoch 11/50
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0259 - val_loss: 0.0643
# Epoch 12/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0239 - val_loss: 0.0606
# Epoch 13/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0204 - val_loss: 0.0472
# Epoch 14/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0383 - val_loss: 0.0458
# Epoch 15/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0252 - val_loss: 0.0442
# Epoch 16/50
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0161 - val_loss: 0.1641
# Epoch 17/50
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0196 - val_loss: 0.0486
# Epoch 18/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0227 - val_loss: 0.1730
# Epoch 19/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0231 - val_loss: 0.0637
# Epoch 20/50
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0198 - val_loss: 0.0763
# Epoch 21/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0155 - val_loss: 0.0349
# Epoch 22/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0150 - val_loss: 0.0282
# Epoch 23/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0235 - val_loss: 0.0273
# Epoch 24/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0115 - val_loss: 0.0383
# Epoch 25/50
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0153 - val_loss: 0.1358
# Epoch 26/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0218 - val_loss: 0.0550
# Epoch 27/50
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0134 - val_loss: 0.0308
# Epoch 28/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0107 - val_loss: 0.0533
# Epoch 29/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0165 - val_loss: 0.0431
# Epoch 30/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0189 - val_loss: 0.0893
# Epoch 31/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0105 - val_loss: 0.0547
# Epoch 32/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0267 - val_loss: 0.0828
# Epoch 33/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0107 - val_loss: 0.1047
# Epoch 34/50
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0094 - val_loss: 0.0363
# Epoch 35/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0179 - val_loss: 0.0406
# Epoch 36/50
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0174 - val_loss: 0.0364
# Epoch 37/50
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0117 - val_loss: 0.0608
# Epoch 38/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0182 - val_loss: 0.0266
# Epoch 39/50
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0200 - val_loss: 0.0606
# Epoch 40/50
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0084 - val_loss: 0.0362
# Epoch 41/50
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0095 - val_loss: 0.0233
# Epoch 42/50
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0150 - val_loss: 0.0278
# Epoch 43/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0096 - val_loss: 0.0205
# Epoch 44/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0085 - val_loss: 0.1000
# Epoch 45/50
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0255 - val_loss: 0.0412
# Epoch 46/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0113 - val_loss: 0.0483
# Epoch 47/50
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0165 - val_loss: 0.0547
# Epoch 48/50
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0083 - val_loss: 0.0477
# Epoch 49/50
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0102 - val_loss: 0.0374
# Epoch 50/50
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0112 - val_loss: 0.0304

# %%
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %%
pred_Y = model.predict(X_test)

pred_Y  = scaler_X.inverse_transform(np.array(pred_Y ).reshape(-1,1))
Y_test = scaler_X.inverse_transform(np.array(Y_test).reshape(-1,1))
# Out:
# 1/1 [==============================] - 1s 929ms/step

# %%
# this is a wrong way to do....

plt.plot(Y_test, label='prediction target')
plt.plot(pred_Y, label='prediction forecast')

# %%
pred_test = []
for xi in X_test:
  yi = model.predict(xi.reshape(1,-1,1))[0,0]
  pred_test.append(yi)

pred_test  = scaler_X.inverse_transform(np.array(pred_test).reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
plt.plot(Y_test, label='prediction target')
plt.plot(pred_test, label='prediction forecast')

# %%
X_train.shape
# Out:
# (108, 8, 1)

# %%
X_test.shape
# Out:
# (28, 8, 1)
